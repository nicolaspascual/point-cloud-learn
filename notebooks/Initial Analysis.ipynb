# %%
import sys; sys.path.append('../')

from src.data_loader import load_data
# Out:
# /home/nicolas/.local/share/virtualenvs/TFM-r40leOZq/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/nicolas/.local/share/virtualenvs/TFM-r40leOZq/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
clusters, points = load_data('../data/sample_input.txt')

# %%
clusters.describe()
# Out:
#                 x           y           z    n_points     n_order      volume  \
# count  152.000000  152.000000  152.000000  152.000000  152.000000  152.000000
# mean   -40.859583  189.827119  -20.047486  163.888158   43.578947    0.097626
# std      3.060522    3.033900    2.938219   99.268487  112.636703    0.345105
# min    -45.640667  182.917550  -25.991330    3.000000    5.000000    0.000268
# 25%    -43.112383  187.681948  -22.434467   78.750000    8.000000    0.002525
# 50%    -41.578875  189.921109  -19.912028  155.000000   14.500000    0.008983
# 75%    -38.834675  192.040960  -17.930611  250.250000   31.000000    0.044103
# max    -34.012400  195.304053  -13.784000  336.000000  986.000000    2.456845
#
#        positive_volume  negative_volume        area  confidence  ...  \
# count       152.000000       152.000000  152.000000       152.0  ...
# mean          0.021045         0.076581    0.174751       100.0  ...
# std           0.063471         0.307650    0.623686         0.0  ...
# min           0.000000         0.000000    0.000107       100.0  ...
# 25%           0.000255         0.001044    0.011627       100.0  ...
# 50%           0.002452         0.005316    0.040033       100.0  ...
# 75%           0.010719         0.024777    0.112355       100.0  ...
# max           0.462109         2.263439    6.276741       100.0  ...
#
#        intensity_sigma_origin  texture_code_destination  red_mean_destination  \
# count              152.000000                     152.0            152.000000
# mean                29.912602                       3.0             98.195353
# std                 12.432943                       0.0             25.616894
# min                  7.787169                       3.0             43.125000
# 25%                 20.714733                       3.0             74.804622
# 50%                 27.914685                       3.0            104.509756
# 75%                 39.703436                       3.0            116.650000
# max                 68.948967                       3.0            159.222222
#
#        red_sigma_destination  green_mean_destination  green_sigma_destination  \
# count             152.000000              152.000000               152.000000
# mean                9.821558              110.200390                 9.953730
# std                 5.289178               19.704142                 5.311082
# min                 0.000000               67.300000                 0.000000
# 25%                 5.778436               93.692683                 5.987626
# 50%                 9.011448              113.799731                 9.004621
# 75%                12.523764              124.175000                12.819405
# max                25.669312              162.555556                25.238125
#
#        blue_mean_destination  blue_sigma_destination  \
# count             152.000000              152.000000
# mean              103.676884               10.314816
# std                25.260404                5.747125
# min                56.166667                0.000000
# 25%                79.333333                5.921693
# 50%               107.146341                8.975514
# 75%               123.013889               13.482547
# max               166.666667               26.306571
#
#        intensity_mean_destination  intensity_sigma_destination
# count                  152.000000                   152.000000
# mean                    65.964879                    16.390425
# std                     29.759367                     7.952241
# min                     21.166667                     2.449490
# 25%                     40.950000                     9.767301
# 50%                     63.178571                    15.760311
# 75%                     87.500000                    22.244657
# max                    161.000000                    36.515202
#
# [8 rows x 32 columns]

# %%
points.describe()
# Out:
#        texture_code_origin  texture_code_destination     x_origin  \
# count               6624.0                    6624.0  6624.000000
# mean                   1.0                       3.0   -40.443364
# std                    0.0                       0.0     2.813404
# min                    1.0                       3.0   -45.858000
# 25%                    1.0                       3.0   -42.570250
# 50%                    1.0                       3.0   -40.831000
# 75%                    1.0                       3.0   -37.979750
# max                    1.0                       3.0   -33.948000
#
#           y_origin     z_origin  vector_i_origin  vetor_j_origin  \
# count  6624.000000  6624.000000      6624.000000     6624.000000
# mean    189.663784   -20.679095         0.416447       -0.421044
# std       2.903811     3.103699         0.369472        0.379173
# min     182.729000   -26.480000        -0.979900       -0.998900
# 25%     187.201250   -23.436250         0.264075       -0.644225
# 50%     189.737000   -20.157500         0.465350       -0.507350
# 75%     192.241750   -18.276750         0.686550       -0.329600
# max     195.434000   -13.741000         0.989300        0.997600
#
#        vector_k_origin  vector_origin_origin  vector_slope_origin  ...  \
# count      6624.000000           6624.000000          6624.000000  ...
# mean          0.567704            146.160811            53.907269  ...
# std           0.216274             52.675138            15.630893  ...
# min           0.000300              0.064027             3.328039  ...
# 25%           0.430875            120.074513            42.970602  ...
# 50%           0.597550            138.581399            53.308606  ...
# 75%           0.731725            155.679076            64.474853  ...
# max           0.998300            359.685883            89.981853  ...
#
#        horizontal_distance  total_distance  n_points_voxel        angle  \
# count          6624.000000     6624.000000     6624.000000  6624.000000
# mean              0.020066        0.126332        3.760719     0.226141
# std               0.015987        0.106208       28.756827     0.288957
# min               0.000240        0.026552        0.000000     0.000000
# 25%               0.009625        0.050860        0.000000     0.053903
# 50%               0.015196        0.085238        0.000000     0.116076
# 75%               0.024795        0.162978        0.000000     0.261541
# max               0.095338        0.507127      336.000000     1.562883
#
#           angle_2n  min_distance  mean_dsitance  max_distance  std_distance  \
# count  6624.000000   6624.000000    6624.000000   6624.000000   6624.000000
# mean      3.253023     -0.133176       0.070846      0.208635      0.098512
# std       1.478697      0.149978       0.080001      0.152429      0.080425
# min       0.000000     -0.499978      -0.498943     -0.498943      0.000000
# 25%       2.245537     -0.208664       0.026754      0.091364      0.038638
# 50%       2.684636     -0.089985       0.055141      0.169390      0.072075
# 75%       4.836744     -0.039836       0.110273      0.318435      0.139726
# max       6.272075      0.466200       0.477365      0.499993      0.482292
#
#             n_dist
# count  6624.000000
# mean     20.159722
# std      11.797597
# min       1.000000
# 25%      11.000000
# 50%      19.000000
# 75%      27.000000
# max      75.000000
#
# [8 rows x 49 columns]
