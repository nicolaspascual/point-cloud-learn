# %%
import sys; sys.path.append('../')

from src.data_loader import load_data
# Out:
# /home/nicolas/.local/share/virtualenvs/TFM-r40leOZq/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/nicolas/.local/share/virtualenvs/TFM-r40leOZq/lib/python3.7/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
clusters, points = load_data('../data/big_sample_input_classiffied.txt')

# %%
clusters.describe()
# Out:
#                  x            y            z     n_points      n_order  \
# count  1050.000000  1050.000000  1050.000000  1050.000000  1050.000000
# mean    -38.120891   234.571629    38.085098  3260.917143    53.801905
# std       6.145920    31.189281    31.750538  1777.262687   152.432869
# min     -56.002600   177.373485   -13.104286    16.000000    10.000000
# 25%     -43.179971   210.411284    12.586461  1691.500000    13.000000
# 50%     -37.591150   229.244054    29.731674  3350.000000    19.000000
# 75%     -32.864562   259.645657    69.493840  4868.500000    37.000000
# max     -27.146750   320.017000   110.750316  6284.000000  3027.000000
#
#             volume  positive_volume  negative_volume         area  \
# count  1050.000000      1050.000000      1050.000000  1050.000000
# mean      0.083430         0.031054         0.052376     0.134822
# std       0.239535         0.141297         0.144822     0.441432
# min       0.000994         0.000000         0.000000     0.000018
# 25%       0.009376         0.000551         0.003376     0.022586
# 50%       0.021690         0.004940         0.012411     0.053120
# 75%       0.056098         0.020121         0.035766     0.116499
# max       4.129203         3.450324         2.279216    11.381278
#
#         confidence  ...  red_mean_destination  red_sigma_destination  \
# count  1050.000000  ...           1050.000000            1050.000000
# mean     99.952381  ...             89.603120              25.240241
# std       1.543033  ...             47.055221              12.169501
# min      50.000000  ...             21.600000               3.207803
# 25%     100.000000  ...             53.707979              15.875247
# 50%     100.000000  ...             68.491935              23.128174
# 75%     100.000000  ...            123.191489              33.216380
# max     100.000000  ...            239.833333              84.020665
#
#        green_mean_destination  green_sigma_destination  blue_mean_destination  \
# count             1050.000000              1050.000000            1050.000000
# mean                -0.359659               166.643652              50.170197
# std                  0.273650                81.969412              20.434385
# min                 -0.968900                 0.395251               0.236054
# 25%                 -0.551000               119.562710              37.453716
# 50%                 -0.369350               162.461241              52.981970
# 75%                 -0.170525               212.414419              65.423670
# max                  0.689200               359.198460              89.987212
#
#        blue_sigma_destination  intensity_mean_destination  \
# count             1050.000000                 1050.000000
# mean               167.772557                   47.756362
# std                 85.194665                   22.566306
# min                  0.443229                    0.603643
# 25%                118.304313                   31.808764
# 50%                161.693301                   50.652643
# 75%                213.896489                   65.817041
# max                359.823930                   89.470700
#
#        intensity_sigma_destination  file_origin  file_destination
# count                  1050.000000  1050.000000       1050.000000
# mean                      2.107832     0.291854          0.832621
# std                       1.203917     0.165636          1.047525
# min                       0.430714     0.022959          0.010074
# 25%                       1.233112     0.181584          0.163602
# 50%                       1.680138     0.255482          0.532163
# 75%                       2.660975     0.351013          1.100892
# max                       6.388965     1.190008         10.722761
#
# [8 rows x 34 columns]

# %%
points.describe()
# Out:
#        texture_code_origin  texture_code_destination      x_origin  \
# count              56492.0                   56492.0  56492.000000
# mean                   1.0                       1.0    -35.408822
# std                    0.0                       0.0      5.775544
# min                    1.0                       1.0    -56.158000
# 25%                    1.0                       1.0    -39.294250
# 50%                    1.0                       1.0    -34.364000
# 75%                    1.0                       1.0    -30.870000
# max                    1.0                       1.0    -25.235000
#
#            y_origin      z_origin  vector_i_origin  vetor_j_origin  \
# count  56492.000000  56492.000000     56492.000000    56492.000000
# mean     218.696767     21.252821         0.131675       -0.395830
# std       26.081572     26.528752         0.430439        0.598986
# min      176.673000    -16.347000        -0.999400       -1.000000
# 25%      200.868000      3.651750        -0.193100       -0.813700
# 50%      212.543500     14.712000         0.180000       -0.639100
# 75%      229.267000     30.153000         0.478125       -0.286900
# max      320.145000    110.914000         0.998800        1.000000
#
#        vector_k_origin  vector_origin_origin  vector_slope_origin  ...  \
# count     56492.000000          56492.000000         56492.000000  ...
# mean          0.470909            173.963133            60.476149  ...
# std           0.245305             76.026418            16.910558  ...
# min           0.000000              0.002165             0.402698  ...
# 25%           0.271400            134.764299            47.810795  ...
# 50%           0.490400            163.887835            60.631017  ...
# 75%           0.671600            199.370725            74.251993  ...
# max           1.000000            359.996537            89.999578  ...
#
#        horizontal_distance  total_distance  n_points_voxel         angle  \
# count         56492.000000    56492.000000    56492.000000  56492.000000
# mean              0.037894        0.188534       60.609697      0.352956
# std               0.019821        0.122854      502.620479      0.338669
# min               0.000011        0.035679        0.000000      0.000000
# 25%               0.022794        0.085452        0.000000      0.111572
# 50%               0.035020        0.150884        0.000000      0.241513
# 75%               0.050597        0.269357        0.000000      0.472957
# max               0.099740        0.507875     6284.000000      1.570329
#
#            angle_2n  min_distance  mean_dsitance  max_distance  std_distance  \
# count  56492.000000  56492.000000   56492.000000  56492.000000  56492.000000
# mean       3.218301     -0.098236       0.040224      0.167723      0.105899
# std        1.610629      0.202870       0.160742      0.202754      0.104520
# min        0.000000     -0.499997      -0.499972     -0.499972      0.000000
# 25%        2.346486     -0.231333      -0.033621      0.059130      0.020605
# 50%        3.017238     -0.093772       0.037616      0.171998      0.073109
# 75%        4.111221      0.022471       0.120346      0.318704      0.165611
# max        6.280758      0.499846       0.499846      0.499999      0.494832
#
#              n_dist
# count  56492.000000
# mean       3.921387
# std        2.374998
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max       20.000000
#
# [8 rows x 46 columns]

# %%
# %matplotlib inline
clusters.classification.hist()

# %%
from sklearn.model_selection import StratifiedShuffleSplit
train_percentage = 0.8

data = clusters.replace('None', np.nan).dropna(axis=1)
X = data.drop('classification', axis=1)
y = data['classification']

train_indexes, test_indexes = next(StratifiedShuffleSplit(n_splits=1, train_size=0.8).split(X, y))
X_train, y_train = X.iloc[train_indexes], y.iloc[train_indexes]
X_test, y_test = X.iloc[test_indexes], y.iloc[test_indexes]

# %%
from sklearn.svm import SVC

model = SVC().fit(X_train, y_train)
# Out:
# /home/nicolas/.local/share/virtualenvs/TFM-r40leOZq/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

classes = y_test.unique()
pd.DataFrame(confusion_matrix(y_test, model.predict(X_test), labels=classes), index=classes, columns=classes)
# Out:
#               Vegetation  Limit_effect  Candidate
# Vegetation           193             2          0
# Limit_effect          12             2          0
# Candidate              1             0          0

# %%
from sklearn.naive_bayes import BernoulliNB

model = BernoulliNB().fit(X_train, y_train)

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier().fit(X_train, y_train)
